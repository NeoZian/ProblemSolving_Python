# %%
r=0
for i in range(1,101):
    print(i,"+",r,"=",(r+i))
    r=r+i

    
 
print(r)
# Out:
# 1 + 0 = 1
# 2 + 1 = 3
# 3 + 3 = 6
# 4 + 6 = 10
# 5 + 10 = 15
# 6 + 15 = 21
# 7 + 21 = 28
# 8 + 28 = 36
# 9 + 36 = 45
# 10 + 45 = 55
# 11 + 55 = 66
# 12 + 66 = 78
# 13 + 78 = 91
# 14 + 91 = 105
# 15 + 105 = 120
# 16 + 120 = 136
# 17 + 136 = 153
# 18 + 153 = 171
# 19 + 171 = 190
# 20 + 190 = 210
# 21 + 210 = 231
# 22 + 231 = 253
# 23 + 253 = 276
# 24 + 276 = 300
# 25 + 300 = 325
# 26 + 325 = 351
# 27 + 351 = 378
# 28 + 378 = 406
# 29 + 406 = 435
# 30 + 435 = 465
# 31 + 465 = 496
# 32 + 496 = 528
# 33 + 528 = 561
# 34 + 561 = 595
# 35 + 595 = 630
# 36 + 630 = 666
# 37 + 666 = 703
# 38 + 703 = 741
# 39 + 741 = 780
# 40 + 780 = 820
# 41 + 820 = 861
# 42 + 861 = 903
# 43 + 903 = 946
# 44 + 946 = 990
# 45 + 990 = 1035
# 46 + 1035 = 1081
# 47 + 1081 = 1128
# 48 + 1128 = 1176
# 49 + 1176 = 1225
# 50 + 1225 = 1275
# 51 + 1275 = 1326
# 52 + 1326 = 1378
# 53 + 1378 = 1431
# 54 + 1431 = 1485
# 55 + 1485 = 1540
# 56 + 1540 = 1596
# 57 + 1596 = 1653
# 58 + 1653 = 1711
# 59 + 1711 = 1770
# ...
